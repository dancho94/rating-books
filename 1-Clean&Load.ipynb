# %%
# !pip install pandas
# !pip install numpy
import pandas as pd 
import numpy as np

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\danil\\venv\\rating-books'

# %%
os.chdir('C:\\Users\\danil\\venv\\rating-books\\data')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'books.csv', 'ratings.csv', 'users.csv']

# %%
df = pd.read_csv('books.csv')
df.head(-5)
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11113   45617  O Cavalo e o Seu Rapaz (As Crónicas de Nárnia ...
# 11114   45623   O Sobrinho do Mágico (As Crónicas de Nárnia  #1)
# 11115   45625  A Viagem do Caminheiro da Alvorada (As Crónica...
# 11116   45626     O Príncipe Caspian (As Crónicas de Nárnia  #4)
# 11117   45630                                  Whores for Gloria
#
#                                            authors  average_rating  \
# 0                       J.K. Rowling/Mary GrandPré            4.57
# ...

# %%
#Delete columns
df.drop('bookID', axis=1, inplace=True)
df.drop('isbn', axis=1, inplace=True)
df.drop('isbn13', axis=1, inplace=True)

# %%
df.head(-5)
# Out:
#                                                    title  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 2      Harry Potter and the Chamber of Secrets (Harry...
# 3      Harry Potter and the Prisoner of Azkaban (Harr...
# 4      Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                  ...
# 11113  O Cavalo e o Seu Rapaz (As Crónicas de Nárnia ...
# 11114   O Sobrinho do Mágico (As Crónicas de Nárnia  #1)
# 11115  A Viagem do Caminheiro da Alvorada (As Crónica...
# 11116     O Príncipe Caspian (As Crónicas de Nárnia  #4)
# 11117                                  Whores for Gloria
#
#                                            authors  average_rating  \
# 0                       J.K. Rowling/Mary GrandPré            4.57
# 1                       J.K. Rowling/Mary GrandPré            4.49
# 2                                     J.K. Rowling            4.42
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               11123 non-null  object
#  1   authors             11123 non-null  object
#  2   average_rating      11123 non-null  float64
#  3   language_code       11123 non-null  object
#  4     num_pages         11123 non-null  int64
#  5   ratings_count       11123 non-null  int64
#  6   text_reviews_count  11123 non-null  int64
#  7   publication_date    11123 non-null  object
#  8   publisher           11123 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 782.2+ KB

# %%
#Transfor column "publication date" for datetime
df['publication_date'] = pd.to_datetime(df['publication_date'] , format='%m/%d/%Y', errors='coerce')
df.head()
# Out:
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating language_code    num_pages  \
# 0  J.K. Rowling/Mary GrandPré            4.57           eng          652
# 1  J.K. Rowling/Mary GrandPré            4.49           eng          870
# 2                J.K. Rowling            4.42           eng          352
# 3  J.K. Rowling/Mary GrandPré            4.56           eng          435
# 4  J.K. Rowling/Mary GrandPré            4.78           eng         2690
#
#    ratings_count  text_reviews_count publication_date        publisher
# 0        2095690               27591       2006-09-16  Scholastic Inc.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               11123 non-null  object
#  1   authors             11123 non-null  object
#  2   average_rating      11123 non-null  float64
#  3   language_code       11123 non-null  object
#  4     num_pages         11123 non-null  int64
#  5   ratings_count       11123 non-null  int64
#  6   text_reviews_count  11123 non-null  int64
#  7   publication_date    11121 non-null  datetime64[ns]
#  8   publisher           11123 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 782.2+ KB

# %%
result = df['language_code'].value_counts().reset_index()
result
# Out:
#    language_code  count
# 0            eng   8908
# 1          en-US   1408
# 2            spa    218
# 3          en-GB    214
# 4            fre    144
# 5            ger     99
# 6            jpn     46
# 7            mul     19
# 8            zho     14
# 9            grc     11
# 10           por     10
# 11         en-CA      7
# 12           ita      5
# 13           enm      3
# 14           lat      3
# 15           swe      2
# 16           rus      2
# 17           srp      1
# 18            nl      1
# 19           msa      1
# 20           glg      1
# 21           wel      1
# 22           ara      1
# 23           nor      1
# 24           tur      1
# 25           gla      1
# 26           ale      1

# %%
df['publisher'].value_counts().reset_index()
# Out:
#                         publisher  count
# 0                         Vintage    318
# 1                   Penguin Books    261
# 2                Penguin Classics    184
# 3                   Mariner Books    150
# 4                Ballantine Books    144
# ...                           ...    ...
# 2285  University of Calgary Press      1
# 2286            Marlowe & Company      1
# 2287  University Press of America      1
# 2288              Abstract Studio      1
# 2289                    VeloPress      1
#
# [2290 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# title                 0
# authors               0
# average_rating        0
# language_code         0
#   num_pages           0
# ratings_count         0
# text_reviews_count    0
# publication_date      2
# publisher             0
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11121 entries, 0 to 11122
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               11121 non-null  object
#  1   authors             11121 non-null  object
#  2   average_rating      11121 non-null  float64
#  3   language_code       11121 non-null  object
#  4     num_pages         11121 non-null  int64
#  5   ratings_count       11121 non-null  int64
#  6   text_reviews_count  11121 non-null  int64
#  7   publication_date    11121 non-null  datetime64[ns]
#  8   publisher           11121 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 868.8+ KB

# %%
df.head()
# Out:
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating language_code    num_pages  \
# 0  J.K. Rowling/Mary GrandPré            4.57           eng          652
# 1  J.K. Rowling/Mary GrandPré            4.49           eng          870
# 2                J.K. Rowling            4.42           eng          352
# 3  J.K. Rowling/Mary GrandPré            4.56           eng          435
# 4  J.K. Rowling/Mary GrandPré            4.78           eng         2690
#
#    ratings_count  text_reviews_count publication_date        publisher
# 0        2095690               27591       2006-09-16  Scholastic Inc.
# ...

# %%
df.to_csv('dataclean.csv', index=False)
